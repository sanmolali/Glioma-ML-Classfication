# %%
# !conda env create -f environment.yml
# !pip install ipykernel
# !python -m ipykernel install --user --name JupyterLab --display-name "Python (JupyterLab)"
# Out:
# CondaValueError: prefix already exists: /home/kbanerj1/.conda/envs/JupyterLab
#
# Requirement already satisfied: ipykernel in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (6.29.5)
# Requirement already satisfied: comm>=0.1.1 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipykernel) (1.8.5)
# Requirement already satisfied: ipython>=7.23.1 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipykernel) (8.18.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipykernel) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipykernel) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipykernel) (24.1)
# Requirement already satisfied: psutil in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipykernel) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipykernel) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipykernel) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (2.18.0)
# Requirement already satisfied: stack-data in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: typing-extensions in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (4.12.2)
# Requirement already satisfied: exceptiongroup in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel) (8.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel) (2.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.3)
# Requirement already satisfied: zipp>=3.20 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel) (3.20.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: six>=1.5 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.4.1)
# Requirement already satisfied: pure-eval in /home/kbanerj1/.conda/envs/JupyterLab/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.3)
# Installed kernelspec JupyterLab in /home/kbanerj1/.local/share/jupyter/kernels/jupyterlab

# %%
import os
import pandas as pd
import glob
import time

# %%
print("Current Directory:", os.getcwd())

# %% [markdown]
# ## Reading Gene Data

# %%
def read_gene_df(filepath, filename):
    '''
    Function that reads a gene file and processes the gene data with the file name.
    Skips rows with unwanted gene names (e.g., N_unmapped, N_multimapping, N_noFeature, N_ambiguous).
    Retains only the tpm_unstranded column.
    '''
    
    df1 = pd.read_csv(filepath, sep='\t', skiprows=1)
    unwanted_genes = ['N_unmapped', 'N_multimapping', 'N_noFeature', 'N_ambiguous']
    df1 = df1[~df1['gene_id'].isin(unwanted_genes)]
    df1 = df1[['gene_name', 'tpm_unstranded']]
    df1.set_index('gene_name', inplace=True)
    df1 = df1.T
    processed_filename = filename.split('.')[0]
    df1.index = [processed_filename]
    df1 = df1.reset_index()
    df1.rename(columns={'index': 'file_name'}, inplace=True)
    
    return df1

# %% [markdown]
# ## First Need to download data using gdc-cleint

# %%
filelist = glob.glob(os.path.join(os.getcwd(),"data/*/*.tsv"))
filelist

# %%
# Get the list of file paths
# filelist = glob.glob("./data/*/*.tsv")
all_dfs = []

for filepath in filelist:
    filename =  os.path.basename(filepath)  # get filename from path
    df = read_gene_df(filepath, filename)
    all_dfs.append(df) 

combined_df = pd.concat(all_dfs, ignore_index=True)
combined_df
# Out:
# gene_name                             file_name    TSPAN6    TNMD     DPM1  \
# 0          e99de328-1950-4739-a59b-e0685c45b94b   29.7759  0.1208  49.7936
# 1          a6384a57-0d59-4e92-8ca2-07bd22cf906f   56.2901  0.0737  83.4729
# 2          933a9a9c-26e4-4209-86f3-f18b812bfbdc   66.3745  0.5016  75.2411
# 3          7412a444-9fad-4d96-a4d4-2c270045919a   57.2746  0.5082  92.0853
# 4          325f91c9-70b9-4285-a7ff-0b7b6280a8ed  128.4459  7.0286  84.6279
# ..                                          ...       ...     ...      ...
# 658        f053a1a1-718a-46bd-a761-8ed3511aeb57   44.7003  0.0803  55.1775
# 659        602acda6-a90d-42bc-a8aa-6eade2a791c4   47.4886  0.3089  66.6481
# 660        4b228438-6c20-4c56-8633-e1873d1aee8c   43.6628  0.4114  65.7862
# 661        04d8f7fc-783b-4c42-89cc-35d603174e5b   25.1427  0.3060  41.0510
# 662        715bd371-4f22-4f97-a9df-ebaf34715a1e   71.9935  0.2046  86.3821
#
# gene_name   SCYL3  C1orf112      FGR      CFH    FUCA2     GCLC  ...  \
# 0          4.7416    2.6487   9.8434  13.0292  11.4386  20.3905  ...
# 1          6.5013   12.3590   0.0322   0.0068  27.7641   1.1546  ...
# 2          5.3781    3.8030  17.9505   1.9869  15.8284  74.2166  ...
# 3          5.6865    2.9126  18.4282  27.8222  52.6998  14.0285  ...
# 4          5.7158    5.8681  17.5790  10.0602  70.3848  21.2514  ...
# ..            ...       ...      ...      ...      ...      ...  ...
# 658        5.8021    2.0247   4.6252   1.1732   4.7872  42.5586  ...
# 659        5.7443    4.0697  13.6360   9.4849  52.6728  14.5572  ...
# 660        6.5181    2.7338   6.8011   2.2545  12.0243  36.5026  ...
# 661        7.8615    6.5292   6.5307  14.5350  16.8377  11.6456  ...
# 662        8.5481    9.8149   3.2686   3.5427  26.9714  38.3417  ...
#
# gene_name  AL451106.1  AC092910.4  AC073611.1  AC136977.1  AC078856.1  \
# 0                 0.0      0.0000      0.2921         0.0      0.0000
# 1                 0.0      1.8124      0.2671         0.0      3.5654
# 2                 0.0      0.0000      0.3681         0.0      0.0000
# 3                 0.0      0.0000      0.5025         0.0      0.0000
# 4                 0.0      0.0000      0.3641         0.0      0.0000
# ..                ...         ...         ...         ...         ...
# 658               0.0      0.0000      0.7070         0.0      0.0000
# 659               0.0      0.0000      0.2629         0.0      0.0000
# 660               0.0      0.0000      0.5861         0.0      0.0000
# 661               0.0     11.2918      0.2615         0.0     17.7707
# 662               0.0      0.0000      0.6254         0.0      0.0000
#
# gene_name  AC008763.4  AL592295.6  AC006486.3  AL391628.1  AP006621.6
# 0                 0.0     25.1013         0.0      0.0124      0.7077
# 1                 0.0      6.4693         0.0      0.0226      1.4564
# 2                 0.0     26.3922         0.0      0.0128      1.1752
# 3                 0.0     10.4905         0.0      0.0425      3.2065
# 4                 0.0      8.8325         0.0      0.0166      2.7076
# ..                ...         ...         ...         ...         ...
# 658               0.0     22.6909         0.0      0.0616      4.3028
# 659               0.0     24.3318         0.0      0.0135      2.9467
# 660               0.0     34.1121         0.0      0.0710      2.8467
# 661               0.0      6.0990         0.0      0.0657      1.2636
# 662               0.0     19.0215         0.0      0.0126      4.3148
#
# [663 rows x 60661 columns]

# %%
## sanity check for columns that have all zeros across rows (samples)
zero_read_genes = combined_df.columns[(combined_df == 0).all(axis=0)]
zero_read_genes
# Out:
# Index(['CD99', 'NME1-NME2', 'Z83844.1', 'MCTS2P', 'CORO7-PAM16', 'ICAM4',
#        'AC004837.1', 'AL021546.1', 'PEDS1-UBE2V1', 'VAMP7',
#        ...
#        'CDR1', 'AC114982.2', 'AC114402.2', 'AC084756.2', 'AL031178.2',
#        'ACTL10', 'AC119733.1', 'AL451106.1', 'AC136977.1', 'AC006486.3'],
#       dtype='object', name='gene_name', length=3329)

# %%
# Drop zero count genes
combined_df = combined_df.drop(columns=zero_read_genes)
combined_df
# Out:
# gene_name                             file_name   TSPAN6    TNMD     DPM1  \
# 0          e99de328-1950-4739-a59b-e0685c45b94b  29.7759  0.1208  49.7936
# 1          a6384a57-0d59-4e92-8ca2-07bd22cf906f  56.2901  0.0737  83.4729
# 2          99618995-9556-4c65-a643-43c9354395a7  59.3714  0.1389  43.7528
# 3          5b1cc683-d363-4cb8-b9b2-050c3c541858  30.2841  0.1136  92.6183
# 4          e7e63873-0099-474a-94b1-160a155c1ea3  16.8758  0.3241  56.2293
# ..                                          ...      ...     ...      ...
# 217        e11c6b6a-61cc-48ef-ac4d-221f27d45091  23.7059  0.4353  44.5254
# 218        843f0cc6-cd74-4af8-be28-5fb02b532269  89.1621  4.1974  56.5681
# 219        66cfd7f5-5c5e-4d20-b2b2-c3c592189160  59.8688  0.1680  62.5148
# 220        e3c51e59-d9ff-425c-ade2-2a396333826a  33.4777  0.2491  53.7671
# 221        a4e0b059-6e1e-4e90-b55a-4e043e6ed051  50.9506  0.1954  52.8074
#
# gene_name   SCYL3  C1orf112      FGR      CFH    FUCA2     GCLC  ...  \
# 0          4.7416    2.6487   9.8434  13.0292  11.4386  20.3905  ...
# 1          6.5013   12.3590   0.0322   0.0068  27.7641   1.1546  ...
# 2          4.6948    1.5906   4.7471   1.9091  16.5347  41.5551  ...
# 3          5.8728    4.1862  18.3498   1.6605  24.4281  15.9592  ...
# 4          4.1407    1.1105   5.6585   2.1326  12.6668  22.7295  ...
# ..            ...       ...      ...      ...      ...      ...  ...
# 217        3.2805    1.9987   3.5011   3.6117   8.3267  14.4904  ...
# 218        8.1008    4.5077   8.1289  19.8376  56.2106  26.5987  ...
# 219        6.2605    1.8694  11.2746   3.9081   5.0972  26.1516  ...
# 220        5.0215    6.3026   8.1720   7.9097  25.1466  13.9373  ...
# 221        4.9584    3.4783  16.4870   7.6500  49.2947  19.6222  ...
#
# gene_name  AC010980.1  AC007511.1  AC004233.4  AC092910.4  AC073611.1  \
# 0              1.3224      0.0000      0.0000      0.0000      0.2921
# 1              0.1100      0.0928      0.0000      1.8124      0.2671
# 2              0.2072      0.0000      0.1879      0.0000      0.5874
# 3              0.3392      0.0000      0.2307      0.0000      1.9572
# 4             13.0383      0.0000      0.0940      0.0000      0.4677
# ..                ...         ...         ...         ...         ...
# 217            0.5414      0.0000      0.0631      0.0000      0.3221
# 218            0.8700      0.0000      0.0000      0.0000      0.1812
# 219            0.1463      0.0000      0.0000      0.0000      0.5113
# 220            0.1652      0.2092      0.0000      5.1068      0.2473
# 221            1.2637      0.0000      0.0000      0.0000      0.3880
#
# gene_name  AC078856.1  AC008763.4  AL592295.6  AL391628.1  AP006621.6
# 0              0.0000       0.000     25.1013      0.0124      0.7077
# 1              3.5654       0.000      6.4693      0.0226      1.4564
# 2              1.1200       0.000     23.7052      0.0568      1.9113
# 3              1.3748       0.021      9.6998      0.0436      3.9436
# 4              0.0000       0.000     28.7837      0.0142      2.6037
# ..                ...         ...         ...         ...         ...
# 217            0.0000       0.000     15.9500      0.0429      1.0381
# 218            0.0000       0.000     30.1781      0.0268      2.5353
# 219            0.0000       0.000     29.6109      0.0064      3.1739
# 220           20.0922       0.000      8.1392      0.0637      1.8238
# 221            0.0000       0.000     13.1942      0.0300      0.9728
#
# [222 rows x 56242 columns]

# %% [markdown]
# ## Read clinical and sample data

# %%
# Load clinical data 
clinical_data = pd.read_csv("/home/talal/Documents/Projects/fyp/Glioma-ML-Classifier-with-ANOVA-Feature-Selection/metadata/clinical.tsv", sep='\t')
clinical_data.head()
# Out:
#                                 case_id  case_submitter_id project_id  \
# 0  d420e653-3fb2-432b-9e81-81232a80264d  HCM-BROD-0210-C71  HCMI-CMDC
# 1  d420e653-3fb2-432b-9e81-81232a80264d  HCM-BROD-0210-C71  HCMI-CMDC
# 2  d420e653-3fb2-432b-9e81-81232a80264d  HCM-BROD-0210-C71  HCMI-CMDC
# 3  d420e653-3fb2-432b-9e81-81232a80264d  HCM-BROD-0210-C71  HCMI-CMDC
# 4  d420e653-3fb2-432b-9e81-81232a80264d  HCM-BROD-0210-C71  HCMI-CMDC
#
#   age_at_index age_is_obfuscated  cause_of_death cause_of_death_source  \
# 0          '--             False  Cancer Related                   '--
# 1          '--             False  Cancer Related                   '--
# 2          '--             False  Cancer Related                   '--
# 3          '--             False  Cancer Related                   '--
# 4          '--             False  Cancer Related                   '--
#
#   country_of_residence_at_enrollment days_to_birth days_to_death  ...  \
# 0                                '--        -19586           481  ...
# 1                                '--        -19586           481  ...
# 2                                '--        -19586           481  ...
# 3                                '--        -19586           481  ...
# 4                                '--        -19586           481  ...
#
#   treatment_arm treatment_dose treatment_dose_units treatment_effect  \
# 0           '--            '--                  '--              '--
# 1           '--            '--                  '--              '--
# 2           '--            '--                  '--              '--
# 3           '--            '--                  '--              '--
# 4           '--            '--                  '--              '--
#
#   treatment_effect_indicator treatment_frequency treatment_intent_type  \
# 0                        '--                 '--              Adjuvant
# 1                        '--                 '--              Adjuvant
# 2                        '--                 '--              Adjuvant
# 3                        '--                 '--              Adjuvant
# 4                        '--                 '--           Neoadjuvant
#
#    treatment_or_therapy treatment_outcome                      treatment_type
# 0                    no               '--  Immunotherapy (Including Vaccines)
# 1                    no               '--          Targeted Molecular Therapy
# 2                    no               '--              Radiation Therapy, NOS
# 3                   yes               '--                        Chemotherapy
# 4                    no               '--                                 '--
#
# [5 rows x 158 columns]

# %%
clinical_data.shape
# Out:
# (1386, 158)

# %%
clinical_data.groupby("primary_diagnosis")['case_id'].count()
# Out:
# primary_diagnosis
# Astrocytoma, NOS                 118
# Astrocytoma, anaplastic          240
# Glioblastoma                     434
# Gliosarcoma                        6
# Mixed glioma                     242
# Oligodendroglioma, NOS           202
# Oligodendroglioma, anaplastic    144
# Name: case_id, dtype: int64

# %%
unique_cases_in_clinical = clinical_data['case_submitter_id'].nunique()
case_duplicates = clinical_data['case_submitter_id'].value_counts()
# Display the unique case count and the distribution of duplicates
unique_cases_in_clinical, case_duplicates.head()
# Out:
# (663,
#  case_submitter_id
#  HCM-BROD-0213-C71    8
#  HCM-BROD-0198-C71    7
#  HCM-BROD-0106-C71    7
#  HCM-BROD-0104-C71    7
#  HCM-BROD-0420-C71    7
#  Name: count, dtype: int64)

# %%
# drop duplicates based on 'case_submitter_id'
clinical_data_dedup = clinical_data.drop_duplicates(subset='case_submitter_id', keep='first')
clinical_data_dedup.shape
# Out:
# (663, 158)

# %% [markdown]
# ## Simplify labels to broader categories

# %%
# simplify labels by mapping complex or specific diagnoses to broader categories - dropping 'mixed gliomas'
diagnosis_map = {
    "Astrocytoma, NOS": "Astrocytoma",
    "Astrocytoma, anaplastic": "Astrocytoma",
    "Oligodendroglioma, NOS": "Oligodendroglioma",
    "Oligodendroglioma, anaplastic": "Oligodendroglioma",
    "Glioblastoma": "Glioblastoma"
}

# create a new 'label' column based on the mapping
clinical_data_dedup.loc[:, 'label'] = clinical_data_dedup['primary_diagnosis'].map(diagnosis_map)
clinical_data_dedup.groupby(["primary_diagnosis", "label"])['case_submitter_id'].count()
# Out:
# /tmp/ipykernel_32651/80191726.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clinical_data_dedup.loc[:, 'label'] = clinical_data_dedup['primary_diagnosis'].map(diagnosis_map)
# primary_diagnosis              label
# Astrocytoma, NOS               Astrocytoma           59
# Astrocytoma, anaplastic        Astrocytoma          120
# Glioblastoma                   Glioblastoma         189
# Oligodendroglioma, NOS         Oligodendroglioma    101
# Oligodendroglioma, anaplastic  Oligodendroglioma     72
# Name: case_submitter_id, dtype: int64

# %%
sample_data = pd.read_csv("/home/talal/Documents/Projects/fyp/Glioma-ML-Classifier-with-ANOVA-Feature-Selection/metadata/gdc_sample_sheet.tsv", sep='\t')
# Simplify filenames in sample_data for merging
sample_data['filename_short'] = sample_data['File Name'].apply(lambda x: x.split('.')[0])
sample_data = pd.merge(sample_data, combined_df, left_on='filename_short', right_on='file_name', how='inner')

# Retain relevant columns in sample_data
columns_to_retain = ['File ID', 'File Name', 'Data Category', 'Data Type', 'Project ID', 'Case ID', 'Sample ID', 'Sample Type', 'filename_short']
sample_data = sample_data[columns_to_retain]
sample_data.head()
# Out:
#                                 File ID  \
# 0  4fa35d6c-060b-433b-bc26-8bd7984631cc
# 1  d9c44441-5f47-4532-8ac1-8a0a7a59a6f0
# 2  6807181b-13e7-4f4b-a7d8-9d00f113f6bc
# 3  f23b7ee8-2af9-4db6-9f2e-bbb74ce501c7
# 4  849a5e37-7da5-4d58-9790-9868792456b0
#
#                                            File Name            Data Category  \
# 0  9e60d3ee-fcb2-48dc-8f3a-3171d25bf32d.rna_seq.a...  Transcriptome Profiling
# 1  7835cada-4a04-42d0-bed4-e8af440b5913.rna_seq.a...  Transcriptome Profiling
# 2  517e37c3-64f8-40fa-8b6c-3c74e423ea1a.rna_seq.a...  Transcriptome Profiling
# 3  c8b55027-80ef-4748-940a-1c97e0e12116.rna_seq.a...  Transcriptome Profiling
# 4  5b664467-3c27-4bf4-90f8-4f518a153dd8.rna_seq.a...  Transcriptome Profiling
#
#                         Data Type Project ID            Case ID  \
# 0  Gene Expression Quantification  HCMI-CMDC  HCM-BROD-0210-C71
# 1  Gene Expression Quantification  HCMI-CMDC  HCM-BROD-0209-C71
# 2  Gene Expression Quantification    CPTAC-3          C3L-03266
# 3  Gene Expression Quantification    CPTAC-3          C3L-03727
# 4  Gene Expression Quantification    CPTAC-3          C3L-01887
#
#                Sample ID                   Sample Type  \
# 0  HCM-BROD-0210-C71-85R  Next Generation Cancer Model
# 1  HCM-BROD-0209-C71-85A  Next Generation Cancer Model
# 2           C3L-03266-01                 Primary Tumor
# 3           C3L-03727-01                 Primary Tumor
# 4           C3L-01887-01                 Primary Tumor
#
#                          filename_short
# 0  9e60d3ee-fcb2-48dc-8f3a-3171d25bf32d
# 1  7835cada-4a04-42d0-bed4-e8af440b5913
# 2  517e37c3-64f8-40fa-8b6c-3c74e423ea1a
# 3  c8b55027-80ef-4748-940a-1c97e0e12116
# 4  5b664467-3c27-4bf4-90f8-4f518a153dd8

# %%
sample_data.shape
# Out:
# (707, 9)

# %%
# Merge with the clinical data to get the primary diagnosis and label
merged_data_dedup = sample_data.merge(
    clinical_data_dedup[['case_submitter_id', 'primary_diagnosis', 'label']], 
    how='left', 
    left_on='Case ID', 
    right_on='case_submitter_id'
)

merged_data_dedup
# Out:
#                                   File ID  \
# 0    4fa35d6c-060b-433b-bc26-8bd7984631cc
# 1    d9c44441-5f47-4532-8ac1-8a0a7a59a6f0
# 2    6807181b-13e7-4f4b-a7d8-9d00f113f6bc
# 3    f23b7ee8-2af9-4db6-9f2e-bbb74ce501c7
# 4    849a5e37-7da5-4d58-9790-9868792456b0
# ..                                    ...
# 217  2761c4d4-00a9-4eb5-9166-af4e56677d07
# 218  0997ec63-6fe0-40fb-b0ff-3ddcb14ec7d2
# 219  2c259bc9-5e6a-46c0-b82b-d6f6eb257455
# 220  3ae2f730-7444-4b65-8c75-1f8f18e6047a
# 221  73d57ab1-1757-4af3-b229-90050dcdb9e0
#
#                                              File Name  \
# 0    9e60d3ee-fcb2-48dc-8f3a-3171d25bf32d.rna_seq.a...
# 1    7835cada-4a04-42d0-bed4-e8af440b5913.rna_seq.a...
# 2    517e37c3-64f8-40fa-8b6c-3c74e423ea1a.rna_seq.a...
# 3    c8b55027-80ef-4748-940a-1c97e0e12116.rna_seq.a...
# 4    5b664467-3c27-4bf4-90f8-4f518a153dd8.rna_seq.a...
# ..                                                 ...
# 217  a93d22ba-5cfa-4359-ae53-3309ced4e12a.rna_seq.a...
# 218  b7effa07-1b05-412a-a1ef-54d52d795c90.rna_seq.a...
# 219  0dbfa70d-2a0d-41c4-aca6-b8df6394bb9c.rna_seq.a...
# 220  27ad3b30-97ff-44a4-89f7-5233a3c3596e.rna_seq.a...
# 221  1fbd55b4-c08b-44b8-940e-6538cc79ef68.rna_seq.a...
#
#                Data Category                       Data Type Project ID  \
# 0    Transcriptome Profiling  Gene Expression Quantification  HCMI-CMDC
# 1    Transcriptome Profiling  Gene Expression Quantification  HCMI-CMDC
# 2    Transcriptome Profiling  Gene Expression Quantification    CPTAC-3
# 3    Transcriptome Profiling  Gene Expression Quantification    CPTAC-3
# 4    Transcriptome Profiling  Gene Expression Quantification    CPTAC-3
# ..                       ...                             ...        ...
# 217  Transcriptome Profiling  Gene Expression Quantification    CPTAC-3
# 218  Transcriptome Profiling  Gene Expression Quantification    CPTAC-3
# 219  Transcriptome Profiling  Gene Expression Quantification    CPTAC-3
# 220  Transcriptome Profiling  Gene Expression Quantification    CPTAC-3
# 221  Transcriptome Profiling  Gene Expression Quantification    CPTAC-3
#
#                Case ID              Sample ID                   Sample Type  \
# 0    HCM-BROD-0210-C71  HCM-BROD-0210-C71-85R  Next Generation Cancer Model
# 1    HCM-BROD-0209-C71  HCM-BROD-0209-C71-85A  Next Generation Cancer Model
# 2            C3L-03266           C3L-03266-01                 Primary Tumor
# 3            C3L-03727           C3L-03727-01                 Primary Tumor
# 4            C3L-01887           C3L-01887-01                 Primary Tumor
# ..                 ...                    ...                           ...
# 217          C3L-02041           C3L-02041-02                 Primary Tumor
# 218          C3L-00365           C3L-00365-01                 Primary Tumor
# 219          C3L-02542           C3L-02542-03                 Primary Tumor
# 220          C3L-02970           C3L-02970-03                 Primary Tumor
# 221          C3L-00104           C3L-00104-01                 Primary Tumor
#
#                            filename_short  case_submitter_id  \
# 0    9e60d3ee-fcb2-48dc-8f3a-3171d25bf32d  HCM-BROD-0210-C71
# 1    7835cada-4a04-42d0-bed4-e8af440b5913  HCM-BROD-0209-C71
# 2    517e37c3-64f8-40fa-8b6c-3c74e423ea1a          C3L-03266
# 3    c8b55027-80ef-4748-940a-1c97e0e12116          C3L-03727
# 4    5b664467-3c27-4bf4-90f8-4f518a153dd8          C3L-01887
# ..                                    ...                ...
# 217  a93d22ba-5cfa-4359-ae53-3309ced4e12a          C3L-02041
# 218  b7effa07-1b05-412a-a1ef-54d52d795c90          C3L-00365
# 219  0dbfa70d-2a0d-41c4-aca6-b8df6394bb9c          C3L-02542
# 220  27ad3b30-97ff-44a4-89f7-5233a3c3596e          C3L-02970
# 221  1fbd55b4-c08b-44b8-940e-6538cc79ef68          C3L-00104
#
#     primary_diagnosis         label
# 0        Glioblastoma  Glioblastoma
# 1        Glioblastoma  Glioblastoma
# 2        Glioblastoma  Glioblastoma
# 3        Glioblastoma  Glioblastoma
# 4        Glioblastoma  Glioblastoma
# ..                ...           ...
# 217      Glioblastoma  Glioblastoma
# 218      Glioblastoma  Glioblastoma
# 219      Glioblastoma  Glioblastoma
# 220      Glioblastoma  Glioblastoma
# 221      Glioblastoma  Glioblastoma
#
# [222 rows x 12 columns]

# %%
merged_data_dedup.shape
# Out:
# (222, 12)

# %%
# Group by both primary_diagnosis and label, then count unique case_submitter_ids
merged_data_dedup.groupby(['primary_diagnosis', 'label'])['case_submitter_id'].count()
# Out:
# primary_diagnosis              label
# Astrocytoma, NOS               Astrocytoma          17
# Astrocytoma, anaplastic        Astrocytoma          41
# Glioblastoma                   Glioblastoma         72
# Oligodendroglioma, NOS         Oligodendroglioma    29
# Oligodendroglioma, anaplastic  Oligodendroglioma    25
# Name: case_submitter_id, dtype: int64

# %%
# Filter out samples with non-empty labels
merged_data_dedup = merged_data_dedup[merged_data_dedup['label'].notna()]
merged_data_dedup.shape
# Out:
# (184, 12)

# %% [markdown]
# ## Keep samples that have valid labels

# %%
# merge combined_df with merged_data_dedup to get 'Sample ID'
combined_df_with_sample_id = pd.merge(combined_df, merged_data_dedup[['filename_short', 'Sample ID']], 
    left_on='file_name', right_on='filename_short', how='left')

# Set 'Sample ID' as index, drop unnecessary columns
combined_df_with_sample_id = combined_df_with_sample_id.set_index('Sample ID')
combined_df_with_sample_id = combined_df_with_sample_id.drop(['filename_short', 'file_name'], axis=1)

# Filter combined_df_with_sample_id to only include non-empty labels
filtered_sample_ids = merged_data_dedup['Sample ID'].dropna().unique()
combined_df_with_sample_id = combined_df_with_sample_id.loc[filtered_sample_ids]

# Display the final shape
combined_df_with_sample_id.shape
# Out:
# (184, 56241)

# %% [markdown]
# ## Output the Processed Data

# %%
# Define extraction directory
extraction_dir = "./processed"
os.makedirs(extraction_dir, exist_ok=True)

data_file_path = os.path.join(extraction_dir, 'data.csv')
combined_df_with_sample_id.to_csv(data_file_path, index=True)
print(f"Data saved to {data_file_path}")
# Out:
# Data saved to ./processed/data.csv

# %%
# Extract and save the filtered labels
y = merged_data_dedup.set_index('Sample ID')['label']
labels_file_path = os.path.join(extraction_dir, 'glioma_labels.csv')
y.to_csv(labels_file_path, index=True)
print(f"Labels saved to {labels_file_path}")
# Out:
# Labels saved to ./processed/glioma_labels.csv
